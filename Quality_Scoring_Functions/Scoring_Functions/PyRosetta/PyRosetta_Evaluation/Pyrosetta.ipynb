# %%
import json

# Load configuration and define a global variable
def load_config():
    global config
    with open('config_Pyrosetta.json') as config_file:
        config = json.load(config_file)

# Call the function to load the configuration
load_config()

# %%
import os
import json
import pandas as pd

# Load configuration and define a global variable
def load_config():
    global config
    with open('config_Pyrosetta.json') as config_file:
        config = json.load(config_file)

# Call the function to load the configuration
load_config()

def convert_tsv_to_excel(source_directory, target_directory, subdirectory_name):
    """
    Converts all TSV files found in the source_directory into Excel files
    and saves them into a new subdirectory inside the target_directory.

    Args:
    - source_directory (str): The path to the directory containing TSV files.
    - target_directory (str): The path to the directory where the new subdirectory will be created.
    - subdirectory_name (str): The name of the new subdirectory where Excel files will be saved.
    """
    # Create the new subdirectory path
    new_directory_path = os.path.join(target_directory, subdirectory_name)
    
    # Ensure the new subdirectory exists
    if not os.path.exists(new_directory_path):
        os.makedirs(new_directory_path)
    
    # Iterate over all files in the source directory
    for filename in os.listdir(source_directory):
        if filename.endswith('.tsv'):
            # Construct the full file paths
            source_file_path = os.path.join(source_directory, filename)
            # Change the file extension from .tsv to .xlsx for the output file
            target_file_path = os.path.join(new_directory_path, filename.replace('.tsv', '.xlsx'))
            
            # Load the TSV file
            df = pd.read_csv(source_file_path, sep='\t')
            # Save the dataframe to an Excel file
            df.to_excel(target_file_path, index=False)
            
            #print(f'Converted {filename} to Excel and saved as {os.path.basename(target_file_path)}')

# Example usage
source_directory = config['Pyrosetta_directory']
target_directory = config['output_directories']
subdirectory_name = 'Pyros_excel_TB'

convert_tsv_to_excel(source_directory, target_directory, subdirectory_name)

# %%
import os
import pandas as pd

# Directory containing the Excel files
#directory_path = '/Users/neginmanshour/Desktop/Protein_Peptide_Evaluation/Pyrosetta/Pyros_ex_TF'
directory_path = f"{config['output_directories']}/Pyros_excel_TB"

# List all Excel files in the directory
excel_files = [file for file in os.listdir(directory_path) if file.endswith('.xlsx')]

for file_name in excel_files:
    file_path = os.path.join(directory_path, file_name)
    
    try:
        # Load the Excel file
        df = pd.read_excel(file_path)
        
        # Check if the DataFrame has at least 4 columns
        if df.shape[1] < 4:
            print(f"File {file_name} does not have enough columns.")
            continue
        
        # Rename the columns
        df.columns = ['Pyrosetta_rank', 'alphafold_rank', 'structure_name', 'score']
        
        # Save the modified DataFrame back to the same file
        df.to_excel(file_path, index=False)
        #print(f"Updated columns for file {file_name}")
    
    except Exception as e:
        print(f"An error occurred with file {file_name}: {e}")

print("Column renaming completed for all files.")
# Out:
# Column renaming completed for all files.

# %%
import os
import shutil
import pandas as pd
from openpyxl import load_workbook

def extract_pdb_id_from_dockq(filename):
    """Extracts the PDB ID from a DockQ filename."""
    parts = filename.split('_')
    return parts[0]  # PDB ID is the first part

def extract_pdb_id_from_pyrosetta(filename):
    """Extracts the PDB ID from a PyRosetta filename."""
    parts = filename.split('_')
    return parts[2]  # PDB ID is after 'pyrosetta_scoring'

def copy_pyrosetta_sheets_to_dockq(dockq_dir, pyrosetta_dir, target_directory, subdirectory_name):
    """
    Copies PyRosetta sheets to corresponding DockQ files and saves the results in a new subdirectory inside target_directory.
    
    Args:
    - dockq_dir (str): Directory containing DockQ files.
    - pyrosetta_dir (str): Directory containing PyRosetta files.
    - target_directory (str): Directory where the new subdirectory will be created.
    - subdirectory_name (str): Name of the new subdirectory for saving the results.
    """
    # Create the new subdirectory path
    output_dir = os.path.join(target_directory, subdirectory_name)
    
    # Ensure the new subdirectory exists
    if not os.path.exists(output_dir):
        os.makedirs(output_dir)
    
    dockq_files = os.listdir(dockq_dir)
    pyrosetta_files = os.listdir(pyrosetta_dir)
    
    # Map PyRosetta files to their PDB IDs
    pyrosetta_map = {extract_pdb_id_from_pyrosetta(f).upper(): f for f in pyrosetta_files if 'pyrosetta_scoring' in f}
    
    for dockq_file in dockq_files:
        if dockq_file.endswith('_TB.xlsx') and 'DockQ_data' in dockq_file:
            pdb_id = extract_pdb_id_from_dockq(dockq_file).upper()
            if pdb_id in pyrosetta_map:
                dockq_path = os.path.join(dockq_dir, dockq_file)
                pyrosetta_path = os.path.join(pyrosetta_dir, pyrosetta_map[pdb_id])
                output_path = os.path.join(output_dir, dockq_file)
                
                # Copy the DockQ file to the output directory if it's not already there
                if not os.path.exists(output_path):
                    shutil.copyfile(dockq_path, output_path)
                
                print(f"Processing {dockq_file} and {pyrosetta_map[pdb_id]} for PDB ID {pdb_id}")
                
                pyrosetta_df = pd.read_excel(pyrosetta_path, sheet_name='Sheet1')
                
                with pd.ExcelWriter(output_path, engine='openpyxl', mode='a') as writer:
                    book = load_workbook(output_path)
                    writer.book = book
                    if 'Pyrosetta' in book.sheetnames:
                        std = book['Pyrosetta']
                        book.remove(std)
                    pyrosetta_df.to_excel(writer, sheet_name='Pyrosetta', index=False)
                    
                    print(f'Updated {dockq_file} with PyRosetta data for PDB ID {pdb_id}')
            else:
                print(f"No matching PyRosetta file found for {dockq_file}")

# Replace these paths with the actual paths to your directories
dockq_dir = config['TB_uni']
pyrosetta_dir = f"{config['output_directories']}/Pyros_excel_TB"
target_directory = config['output_directories']
subdirectory_name = 'Pyrosetta_DockQ_TB'

copy_pyrosetta_sheets_to_dockq(dockq_dir, pyrosetta_dir, target_directory, subdirectory_name)
# Out:
# Processing 8C3H_DockQ_data_TB.xlsx and pyrosetta_scoring_8C3H_TB.xlsx for PDB ID 8C3H
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[5], line 73
#      70 target_directory = config['output_directories']
#      71 subdirectory_name = 'Pyrosetta_DockQ_TB'
# ---> 73 copy_pyrosetta_sheets_to_dockq(dockq_dir, pyrosetta_dir, target_directory, subdirectory_name)
#
# Cell In[5], line 57, in copy_pyrosetta_sheets_to_dockq(dockq_dir, pyrosetta_dir, target_directory, subdirectory_name)
#      55 with pd.ExcelWriter(output_path, engine='openpyxl', mode='a') as writer:
#      56     book = load_workbook(output_path)
# ---> 57     writer.book = book
#      58     if 'Pyrosetta' in book.sheetnames:
#      59         std = book['Pyrosetta']
#
# AttributeError: can't set attribute

# %%
import os
import shutil
import pandas as pd
from openpyxl import load_workbook
import json


def extract_pdb_id_from_dockq(filename):
    """Extracts the PDB ID from a DockQ filename."""
    parts = filename.split('_')
    return parts[0]  # PDB ID is the first part

def extract_pdb_id_from_pyrosetta(filename):
    """Extracts the PDB ID from a PyRosetta filename."""
    parts = filename.split('_')
    return parts[2]  # PDB ID is after 'pyrosetta_scoring'

def copy_pyrosetta_sheets_to_dockq(dockq_dir, pyrosetta_dir, target_directory, subdirectory_name):
    """
    Copies PyRosetta sheets to corresponding DockQ files and saves the results in a new subdirectory inside target_directory.
    
    Args:
    - dockq_dir (str): Directory containing DockQ files.
    - pyrosetta_dir (str): Directory containing PyRosetta files.
    - target_directory (str): Directory where the new subdirectory will be created.
    - subdirectory_name (str): Name of the new subdirectory for saving the results.
    """
    # Create the new subdirectory path
    output_dir = os.path.join(target_directory, subdirectory_name)
    
    # Ensure the new subdirectory exists
    if not os.path.exists(output_dir):
        os.makedirs(output_dir)
    
    dockq_files = os.listdir(dockq_dir)
    pyrosetta_files = os.listdir(pyrosetta_dir)
    
    # Map PyRosetta files to their PDB IDs
    pyrosetta_map = {extract_pdb_id_from_pyrosetta(f).upper(): f for f in pyrosetta_files if 'pyrosetta_scoring' in f}
    
    for dockq_file in dockq_files:
        if dockq_file.endswith('_TB.xlsx') and 'DockQ_data' in dockq_file:
            pdb_id = extract_pdb_id_from_dockq(dockq_file).upper()
            if pdb_id in pyrosetta_map:
                dockq_path = os.path.join(dockq_dir, dockq_file)
                pyrosetta_path = os.path.join(pyrosetta_dir, pyrosetta_map[pdb_id])
                output_path = os.path.join(output_dir, dockq_file)
                
                # Copy the DockQ file to the output directory if it's not already there
                if not os.path.exists(output_path):
                    shutil.copyfile(dockq_path, output_path)
                
                print(f"Processing {dockq_file} and {pyrosetta_map[pdb_id]} for PDB ID {pdb_id}")
                
                pyrosetta_df = pd.read_excel(pyrosetta_path, sheet_name='Sheet1')
                
                # Load the existing workbook
                book = load_workbook(output_path)
                
                # Remove the existing sheet if it exists
                if 'Pyrosetta' in book.sheetnames:
                    std = book['Pyrosetta']
                    book.remove(std)
                
                # Save the updated workbook
                book.save(output_path)
                
                # Add the new sheet to the workbook
                with pd.ExcelWriter(output_path, engine='openpyxl', mode='a') as writer:
                    pyrosetta_df.to_excel(writer, sheet_name='Pyrosetta', index=False)
                
                print(f'Updated {dockq_file} with PyRosetta data for PDB ID {pdb_id}')
            else:
                print(f"No matching PyRosetta file found for {dockq_file}")

# Use the paths from the already loaded config dictionary
dockq_dir = config['TB_uni']
pyrosetta_dir = f"{config['output_directories']}/Pyros_excel_TB"
target_directory = config['output_directories']
subdirectory_name = 'Pyrosetta_DockQ_TB'

copy_pyrosetta_sheets_to_dockq(dockq_dir, pyrosetta_dir, target_directory, subdirectory_name)
# Out:
# Processing 8C3H_DockQ_data_TB.xlsx and pyrosetta_scoring_8C3H_TB.xlsx for PDB ID 8C3H
# Updated 8C3H_DockQ_data_TB.xlsx with PyRosetta data for PDB ID 8C3H
# Processing 7QOX_DockQ_data_TB.xlsx and pyrosetta_scoring_7QOX_TB.xlsx for PDB ID 7QOX
# Updated 7QOX_DockQ_data_TB.xlsx with PyRosetta data for PDB ID 7QOX
# Processing 8F8Z_DockQ_data_TB.xlsx and pyrosetta_scoring_8F8Z_TB.xlsx for PDB ID 8F8Z
# Updated 8F8Z_DockQ_data_TB.xlsx with PyRosetta data for PDB ID 8F8Z
# Processing 8CK5_DockQ_data_TB.xlsx and pyrosetta_scoring_8CK5_TB.xlsx for PDB ID 8CK5
# Updated 8CK5_DockQ_data_TB.xlsx with PyRosetta data for PDB ID 8CK5
# Processing 8DGM_DockQ_data_TB.xlsx and pyrosetta_scoring_8DGM_TB.xlsx for PDB ID 8DGM
# Updated 8DGM_DockQ_data_TB.xlsx with PyRosetta data for PDB ID 8DGM
# Processing 7XV1_DockQ_data_TB.xlsx and pyrosetta_scoring_7XV1_TB.xlsx for PDB ID 7XV1
# Updated 7XV1_DockQ_data_TB.xlsx with PyRosetta data for PDB ID 7XV1
# Processing 8A68_DockQ_data_TB.xlsx and pyrosetta_scoring_8A68_TB.xlsx for PDB ID 8A68
# Updated 8A68_DockQ_data_TB.xlsx with PyRosetta data for PDB ID 8A68
# Processing 7ZAX_DockQ_data_TB.xlsx and pyrosetta_scoring_7ZAX_TB.xlsx for PDB ID 7ZAX
# Updated 7ZAX_DockQ_data_TB.xlsx with PyRosetta data for PDB ID 7ZAX
# Processing 7UDL_DockQ_data_TB.xlsx and pyrosetta_scoring_7UDL_TB.xlsx for PDB ID 7UDL
# Updated 7UDL_DockQ_data_TB.xlsx with PyRosetta data for PDB ID 7UDL
# Processing 7PRX_DockQ_data_TB.xlsx and pyrosetta_scoring_7PRX_TB.xlsx for PDB ID 7PRX
# Updated 7PRX_DockQ_data_TB.xlsx with PyRosetta data for PDB ID 7PRX
# Processing 7WQQ_DockQ_data_TB.xlsx and pyrosetta_scoring_7WQQ_TB.xlsx for PDB ID 7WQQ
# Updated 7WQQ_DockQ_data_TB.xlsx with PyRosetta data for PDB ID 7WQQ
# Processing 7V1A_DockQ_data_TB.xlsx and pyrosetta_scoring_7V1A_TB.xlsx for PDB ID 7V1A
# Updated 7V1A_DockQ_data_TB.xlsx with PyRosetta data for PDB ID 7V1A
# Processing 7SXF_DockQ_data_TB.xlsx and pyrosetta_scoring_7SXF_TB.xlsx for PDB ID 7SXF
# Updated 7SXF_DockQ_data_TB.xlsx with PyRosetta data for PDB ID 7SXF
# Processing 7Z7C_DockQ_data_TB.xlsx and pyrosetta_scoring_7Z7C_TB.xlsx for PDB ID 7Z7C
# Updated 7Z7C_DockQ_data_TB.xlsx with PyRosetta data for PDB ID 7Z7C
# Processing 8ESE_DockQ_data_TB.xlsx and pyrosetta_scoring_8ESE_TB.xlsx for PDB ID 8ESE
# Updated 8ESE_DockQ_data_TB.xlsx with PyRosetta data for PDB ID 8ESE
# Processing 7XTY_DockQ_data_TB.xlsx and pyrosetta_scoring_7XTY_TB.xlsx for PDB ID 7XTY
# Updated 7XTY_DockQ_data_TB.xlsx with PyRosetta data for PDB ID 7XTY
# Processing 7X8G_DockQ_data_TB.xlsx and pyrosetta_scoring_7X8G_TB.xlsx for PDB ID 7X8G
# Updated 7X8G_DockQ_data_TB.xlsx with PyRosetta data for PDB ID 7X8G
# Processing 8IA5_DockQ_data_TB.xlsx and pyrosetta_scoring_8IA5_TB.xlsx for PDB ID 8IA5
# Updated 8IA5_DockQ_data_TB.xlsx with PyRosetta data for PDB ID 8IA5
# Processing 8D7P_DockQ_data_TB.xlsx and pyrosetta_scoring_8D7P_TB.xlsx for PDB ID 8D7P
# Updated 8D7P_DockQ_data_TB.xlsx with PyRosetta data for PDB ID 8D7P
# Processing 8hep_DockQ_data_TB.xlsx and pyrosetta_scoring_8HEP_TB.xlsx for PDB ID 8HEP
# Updated 8hep_DockQ_data_TB.xlsx with PyRosetta data for PDB ID 8HEP
# Processing 7QWV_DockQ_data_TB.xlsx and pyrosetta_scoring_7QWV_TB.xlsx for PDB ID 7QWV
# Updated 7QWV_DockQ_data_TB.xlsx with PyRosetta data for PDB ID 7QWV
# Processing 8ARE_DockQ_data_TB.xlsx and pyrosetta_scoring_8ARE_TB.xlsx for PDB ID 8ARE
# Updated 8ARE_DockQ_data_TB.xlsx with PyRosetta data for PDB ID 8ARE
# Processing 7UI8_DockQ_data_TB.xlsx and pyrosetta_scoring_7UI8_TB.xlsx for PDB ID 7UI8
# Updated 7UI8_DockQ_data_TB.xlsx with PyRosetta data for PDB ID 7UI8
# Processing 7YUE_DockQ_data_TB.xlsx and pyrosetta_scoring_7YUE_TB.xlsx for PDB ID 7YUE
# Updated 7YUE_DockQ_data_TB.xlsx with PyRosetta data for PDB ID 7YUE
# Processing 8HDJ_DockQ_data_TB.xlsx and pyrosetta_scoring_8HDJ_TB.xlsx for PDB ID 8HDJ
# Updated 8HDJ_DockQ_data_TB.xlsx with PyRosetta data for PDB ID 8HDJ
# Processing 8FK3_DockQ_data_TB.xlsx and pyrosetta_scoring_8FK3_TB.xlsx for PDB ID 8FK3
# Updated 8FK3_DockQ_data_TB.xlsx with PyRosetta data for PDB ID 8FK3
# Processing 8DWK_DockQ_data_TB.xlsx and pyrosetta_scoring_8DWK_TB.xlsx for PDB ID 8DWK
# Updated 8DWK_DockQ_data_TB.xlsx with PyRosetta data for PDB ID 8DWK
# Processing 8HLO_DockQ_data_TB.xlsx and pyrosetta_scoring_8HLO_TB.xlsx for PDB ID 8HLO
# Updated 8HLO_DockQ_data_TB.xlsx with PyRosetta data for PDB ID 8HLO
# Processing 8CIR_DockQ_data_TB.xlsx and pyrosetta_scoring_8CIR_TB.xlsx for PDB ID 8CIR
# Updated 8CIR_DockQ_data_TB.xlsx with PyRosetta data for PDB ID 8CIR
# Processing 8CCW_DockQ_data_TB.xlsx and pyrosetta_scoring_8CCW_TB.xlsx for PDB ID 8CCW
# Updated 8CCW_DockQ_data_TB.xlsx with PyRosetta data for PDB ID 8CCW
# Processing 7UE2_DockQ_data_TB.xlsx and pyrosetta_scoring_7UE2_TB.xlsx for PDB ID 7UE2
# Updated 7UE2_DockQ_data_TB.xlsx with PyRosetta data for PDB ID 7UE2
# Processing 7ZX4_DockQ_data_TB.xlsx and pyrosetta_scoring_7ZX4_TB.xlsx for PDB ID 7ZX4
# Updated 7ZX4_DockQ_data_TB.xlsx with PyRosetta data for PDB ID 7ZX4
# Processing 7UW2_DockQ_data_TB.xlsx and pyrosetta_scoring_7UW2_TB.xlsx for PDB ID 7UW2
# Updated 7UW2_DockQ_data_TB.xlsx with PyRosetta data for PDB ID 7UW2
# Processing 8EBL_DockQ_data_TB.xlsx and pyrosetta_scoring_8EBL_TB.xlsx for PDB ID 8EBL
# Updated 8EBL_DockQ_data_TB.xlsx with PyRosetta data for PDB ID 8EBL
# Processing 7R2M_DockQ_data_TB.xlsx and pyrosetta_scoring_7R2M_TB.xlsx for PDB ID 7R2M
# Updated 7R2M_DockQ_data_TB.xlsx with PyRosetta data for PDB ID 7R2M
# Processing 8CZK_DockQ_data_TB.xlsx and pyrosetta_scoring_8CZK_TB.xlsx for PDB ID 8CZK
# Updated 8CZK_DockQ_data_TB.xlsx with PyRosetta data for PDB ID 8CZK
# Processing 7Y9C_DockQ_data_TB.xlsx and pyrosetta_scoring_7Y9C_TB.xlsx for PDB ID 7Y9C
# Updated 7Y9C_DockQ_data_TB.xlsx with PyRosetta data for PDB ID 7Y9C
# Processing 8AFI_DockQ_data_TB.xlsx and pyrosetta_scoring_8AFI_TB.xlsx for PDB ID 8AFI
# Updated 8AFI_DockQ_data_TB.xlsx with PyRosetta data for PDB ID 8AFI
# Processing 8D51_DockQ_data_TB.xlsx and pyrosetta_scoring_8D51_TB.xlsx for PDB ID 8D51
# Updated 8D51_DockQ_data_TB.xlsx with PyRosetta data for PDB ID 8D51
# Processing 8IA4_DockQ_data_TB.xlsx and pyrosetta_scoring_8IA4_TB.xlsx for PDB ID 8IA4
# Updated 8IA4_DockQ_data_TB.xlsx with PyRosetta data for PDB ID 8IA4
# Processing 7UDK_DockQ_data_TB.xlsx and pyrosetta_scoring_7UDK_TB.xlsx for PDB ID 7UDK
# Updated 7UDK_DockQ_data_TB.xlsx with PyRosetta data for PDB ID 7UDK
# Processing 8FXQ_DockQ_data_TB.xlsx and pyrosetta_scoring_8FXQ_TB.xlsx for PDB ID 8FXQ
# Updated 8FXQ_DockQ_data_TB.xlsx with PyRosetta data for PDB ID 8FXQ
# Processing 8EQ5_DockQ_data_TB.xlsx and pyrosetta_scoring_8EQ5_TB.xlsx for PDB ID 8EQ5
# Updated 8EQ5_DockQ_data_TB.xlsx with PyRosetta data for PDB ID 8EQ5
# Processing 8OEP_DockQ_data_TB.xlsx and pyrosetta_scoring_8OEP_TB.xlsx for PDB ID 8OEP
# Updated 8OEP_DockQ_data_TB.xlsx with PyRosetta data for PDB ID 8OEP
# Processing 8I3G_DockQ_data_TB.xlsx and pyrosetta_scoring_8I3G_TB.xlsx for PDB ID 8I3G
# Updated 8I3G_DockQ_data_TB.xlsx with PyRosetta data for PDB ID 8I3G
# Processing 8BFT_DockQ_data_TB.xlsx and pyrosetta_scoring_8BFT_TB.xlsx for PDB ID 8BFT
# Updated 8BFT_DockQ_data_TB.xlsx with PyRosetta data for PDB ID 8BFT
# Processing 8AHS_DockQ_data_TB.xlsx and pyrosetta_scoring_8AHS_TB.xlsx for PDB ID 8AHS
# Updated 8AHS_DockQ_data_TB.xlsx with PyRosetta data for PDB ID 8AHS
# Processing 7SXJ_DockQ_data_TB.xlsx and pyrosetta_scoring_7SXJ_TB.xlsx for PDB ID 7SXJ
# Updated 7SXJ_DockQ_data_TB.xlsx with PyRosetta data for PDB ID 7SXJ
# Processing 7Z6U_DockQ_data_TB.xlsx and pyrosetta_scoring_7Z6U_TB.xlsx for PDB ID 7Z6U
# Updated 7Z6U_DockQ_data_TB.xlsx with PyRosetta data for PDB ID 7Z6U
# Processing 8C2P_DockQ_data_TB.xlsx and pyrosetta_scoring_8C2P_TB.xlsx for PDB ID 8C2P
# Updated 8C2P_DockQ_data_TB.xlsx with PyRosetta data for PDB ID 8C2P
# Processing 8CZ9_DockQ_data_TB.xlsx and pyrosetta_scoring_8CZ9_TB.xlsx for PDB ID 8CZ9
# Updated 8CZ9_DockQ_data_TB.xlsx with PyRosetta data for PDB ID 8CZ9
# Processing 7Y8F_DockQ_data_TB.xlsx and pyrosetta_scoring_7Y8F_TB.xlsx for PDB ID 7Y8F
# Updated 7Y8F_DockQ_data_TB.xlsx with PyRosetta data for PDB ID 7Y8F
# Processing 8DVL_DockQ_data_TB.xlsx and pyrosetta_scoring_8DVL_TB.xlsx for PDB ID 8DVL
# Updated 8DVL_DockQ_data_TB.xlsx with PyRosetta data for PDB ID 8DVL
# Processing 8BR9_DockQ_data_TB.xlsx and pyrosetta_scoring_8BR9_TB.xlsx for PDB ID 8BR9
# Updated 8BR9_DockQ_data_TB.xlsx with PyRosetta data for PDB ID 8BR9
# Processing 7TO9_DockQ_data_TB.xlsx and pyrosetta_scoring_7TO9_TB.xlsx for PDB ID 7TO9
# Updated 7TO9_DockQ_data_TB.xlsx with PyRosetta data for PDB ID 7TO9
# Processing 7XFG_DockQ_data_TB.xlsx and pyrosetta_scoring_7XFG_TB.xlsx for PDB ID 7XFG
# Updated 7XFG_DockQ_data_TB.xlsx with PyRosetta data for PDB ID 7XFG
# Processing 7SQA_DockQ_data_TB.xlsx and pyrosetta_scoring_7SQA_TB.xlsx for PDB ID 7SQA
# Updated 7SQA_DockQ_data_TB.xlsx with PyRosetta data for PDB ID 7SQA
# Processing 7Z5L_DockQ_data_TB.xlsx and pyrosetta_scoring_7Z5L_TB.xlsx for PDB ID 7Z5L
# Updated 7Z5L_DockQ_data_TB.xlsx with PyRosetta data for PDB ID 7Z5L
# Processing 8B58_DockQ_data_TB.xlsx and pyrosetta_scoring_8B58_TB.xlsx for PDB ID 8B58
# Updated 8B58_DockQ_data_TB.xlsx with PyRosetta data for PDB ID 8B58
# Processing 7ZW4_DockQ_data_TB.xlsx and pyrosetta_scoring_7ZW4_TB.xlsx for PDB ID 7ZW4
# Updated 7ZW4_DockQ_data_TB.xlsx with PyRosetta data for PDB ID 7ZW4

# %%
import os
import pandas as pd

def calculate_spearman_for_directory(directory_path, output_file):
    # List to store results
    results = []

    # Iterate through all files in the directory
    for filename in os.listdir(directory_path):
        if filename.endswith(".xlsx"):
            file_path = os.path.join(directory_path, filename)

            # Load the Excel file
            excel_data = pd.ExcelFile(file_path)

            # Check if the expected sheets exist
            if 'Sheet' in excel_data.sheet_names and 'Pyrosetta' in excel_data.sheet_names:
                # Load the data from each sheet
                sheet_data = pd.read_excel(file_path, sheet_name='Sheet')
                pyrosetta_data = pd.read_excel(file_path, sheet_name='Pyrosetta')

                # Extract relevant columns and rename them for clarity
                sheet_relevant = sheet_data[['File Name', 'DockQ Rank']].rename(columns={'File Name': 'structure_name', 'DockQ Rank': 'dock_rank'})
                pyrosetta_relevant = pyrosetta_data[['structure_name', 'Pyrosetta_rank']]

                # Merge the dataframes based on 'structure_name'
                merged_data = pd.merge(sheet_relevant, pyrosetta_relevant, on='structure_name')

                # Calculate the Spearman correlation
                spearman_corr = merged_data['dock_rank'].corr(merged_data['Pyrosetta_rank'], method='spearman')

                # Append the result to the list
                results.append({'File Name': filename, 'Spearman Correlation': spearman_corr})

    # Create a DataFrame from the results
    results_df = pd.DataFrame(results)

    # Save the results to an Excel file
    results_df.to_excel(output_file, index=False)

# Usage
directory_path = config['output_directories'] + "/Pyrosetta_DockQ_TB"
output_directory = config['Spearman_Correlation_directory_TB']
output_file_path = os.path.join(output_directory, "spearman_correlation_Pyrosetta_TB.xlsx")

calculate_spearman_for_directory(directory_path, output_file_path)

# %%
import pandas as pd

# Load the Excel file
# Make sure to include the file extension, such as '.xlsx', in the file path
file_path = f"{config['Spearman_Correlation_directory_TB']}/spearman_correlation_Pyrosetta_TB.xlsx" # Adjusted file path with extension
try:
    df = pd.read_excel(file_path)

    # Calculate the percentages of positive and negative Spearman correlation values
    positive_percentage = (df['Spearman Correlation'] > 0).mean() * 100
    negative_percentage = (df['Spearman Correlation'] < 0).mean() * 100
    
    # Calculate the average of Spearman Correlation values
    average_correlation = df['Spearman Correlation'].mean()

    # Print the results
    print(f"Percentage of positive correlations: {positive_percentage:.2f}%")
    print(f"Percentage of negative correlations: {negative_percentage:.2f}%")
    print(f"Average Spearman Correlation: {average_correlation:.2f}")
except FileNotFoundError:
    print(f"File not found. Please check the file path: {file_path}")
# Out:
# Percentage of positive correlations: 51.67%
# Percentage of negative correlations: 48.33%
# Average Spearman Correlation: -0.02

# %%
import os
import pandas as pd

# Directory containing the Excel files
directory_path = f"{config['output_directories']}/Pyrosetta_DockQ_TB"

# Initialize a list to store the results
results = []

# List all Excel files in the directory
excel_files = [file for file in os.listdir(directory_path) if file.endswith('.xlsx')]

for file_name in excel_files:
    file_path = os.path.join(directory_path, file_name)
    xls = pd.ExcelFile(file_path)

    # Extract pdb_id from file name
    pdb_id = file_name.split('_')[0]

    # Load data from "Pyrosetta" sheet
    Pyrosetta_df = pd.read_excel(file_path, sheet_name='Pyrosetta')
    structure_name_for_rank_zero = Pyrosetta_df[Pyrosetta_df['Pyrosetta_rank'] == 0]['structure_name'].iloc[0]

    # Load data from "Sheet" sheet
    sheet_df = pd.read_excel(file_path, sheet_name='Sheet')

    # Highest DockQ score
    highest_dockq_score = sheet_df['DockQ'].max()

    # DockQ score for the structure from Pyrosetta
    highest_Pyrosetta_dockq_score = sheet_df[sheet_df['File Name'].str.contains(structure_name_for_rank_zero)]['DockQ'].max()

    # Calculate Loss
    score_Loss = highest_dockq_score - highest_Pyrosetta_dockq_score

    # Append results
    results.append([pdb_id, highest_dockq_score, highest_Pyrosetta_dockq_score, score_Loss])

# Create a DataFrame from the results
results_df = pd.DataFrame(results, columns=['File Name', 'DockQ', 'Pyrosetta ranked', 'Loss'])

# Save the results into a new Excel file
output_directory = config["DockQ_Loss_directory_TB"]
output_path = os.path.join(output_directory, 'Pyrosetta_TB.xlsx')
results_df.to_excel(output_path, index=False)

print(f"Results have been saved to {output_path}")
# Out:
# Results have been saved to /Users/neginmanshour/Desktop/PpEv/Quality_Scoring_Functions/Loss/TB_Loss/Pyrosetta_TB.xlsx
