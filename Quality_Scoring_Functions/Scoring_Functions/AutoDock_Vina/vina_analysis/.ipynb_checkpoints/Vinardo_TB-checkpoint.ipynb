# %%
import os
import pandas as pd

def split_and_save_csv_files(source_directory, vina_directory, vinardo_directory):
    # Ensure the output directories exist
    os.makedirs(vina_directory, exist_ok=True)
    os.makedirs(vinardo_directory, exist_ok=True)
    
    # Iterate through each file in the source directory
    for file in os.listdir(source_directory):
        if file.endswith('.csv'):
            file_path = os.path.join(source_directory, file)
            df = pd.read_csv(file_path)
            
            # Split the dataframe based on the scoring function
            df_vina = df[df['scoring_function'] == 'vina']
            df_vinardo = df[df['scoring_function'] == 'vinardo']
            
            # Define the base filename without extension and the new file paths
            base_filename = file.rsplit('.', 1)[0]
            file_path_vina = os.path.join(vina_directory, f"{base_filename}_vina.xlsx")
            file_path_vinardo = os.path.join(vinardo_directory, f"{base_filename}_vinardo.xlsx")
            
            # Save the dataframes to Excel files
            df_vina.to_excel(file_path_vina, index=False)
            df_vinardo.to_excel(file_path_vinardo, index=False)
            
            #print(f"Processed and saved: {file}")

# Example usage
source_directory = '/Users/neginmanshour/Desktop/Protein_Peptide_Evaluation/Autodock_Vina/Data/Vina_TF'
vina_directory = '/Users/neginmanshour/Desktop/Protein_Peptide_Evaluation/Autodock_Vina/Data/Vina_TF_ex'
vinardo_directory = '/Users/neginmanshour/Desktop/Protein_Peptide_Evaluation/Autodock_Vina/Data/Vinardo_TF_ex'

split_and_save_csv_files(source_directory, vina_directory, vinardo_directory)

# %%
import os
import pandas as pd

def sort_excel_files_in_directory(directory_path, output_directory):
    # Ensure the output directory exists
    if not os.path.exists(output_directory):
        os.makedirs(output_directory)

    # List all Excel files in the directory
    excel_files = [f for f in os.listdir(directory_path) if f.endswith('.xlsx')]

    # Process each file
    for file in excel_files:
        file_path = os.path.join(directory_path, file)
        try:
            # Load the Excel file
            data = pd.read_excel(file_path)

            # Sort the data by the 'total' column
            sorted_data = data.sort_values(by='total', ascending=True)

            # Add a new column 'vinardo_rank' with numbers from 0 to 999
            # Note: Ensure there are at least 1000 rows, otherwise adjust the range accordingly
            if len(sorted_data) >= 1000:
                sorted_data['vinardo_rank'] = range(1000)
            else:
                sorted_data['vinardo_rank'] = range(len(sorted_data))

            # Define the output file path
            output_file_path = os.path.join(output_directory, f'sorted_{file}')

            # Save the sorted data to a new Excel file
            sorted_data.to_excel(output_file_path, index=False)
            
            #print(f'Successfully sorted and saved: {output_file_path}')
        except Exception as e:
            print(f'Error processing file {file}: {e}')

# Usage
directory_path = '/Users/neginmanshour/Desktop/Protein_Peptide_Evaluation/Autodock_Vina/Data/Vinardo_TB_ex'  # Path to the directory containing the Excel files
output_directory = '/Users/neginmanshour/Desktop/Protein_Peptide_Evaluation/Autodock_Vina/Data/Vinardo_TB_ex_sorted'  # Path where sorted Excel files will be saved

sort_excel_files_in_directory(directory_path, output_directory)

# %%
import pandas as pd
import os
import re

input_directory = '/Users/neginmanshour/Desktop/Protein_Peptide_Evaluation/Autodock_Vina/Data/Vinardo_TB_ex_sorted'
output_directory = '/Users/neginmanshour/Desktop/Protein_Peptide_Evaluation/Autodock_Vina/Data/Vinardo_sorted_TB_alpha_rank'

if not os.path.exists(output_directory):
    os.makedirs(output_directory)

def extract_rank(s):
    match = re.search(r'\d+', s)
    return int(match.group()) if match else None

problematic_files = []

for filename in os.listdir(input_directory):
    if filename.endswith('.xlsx') or filename.endswith('.xls'):
        file_path = os.path.join(input_directory, filename)
        output_file_path = os.path.join(output_directory, filename)
        try:
            xls = pd.ExcelFile(file_path, engine='openpyxl')
            dfs = {}
            for sheet_name in xls.sheet_names:
                df = xls.parse(sheet_name)
                if sheet_name == 'Sheet1':
                    df['alphafold rank'] = df['file'].apply(extract_rank)
                    cols = ['alphafold rank'] + [col for col in df if col != 'alphafold rank']
                    df = df[cols]
                    df = df[~df['file'].str.contains("native", case=False, na=False)]
                dfs[sheet_name] = df
            with pd.ExcelWriter(output_file_path, engine='openpyxl') as writer:
                for sheet_name, df in dfs.items():
                    df.to_excel(writer, sheet_name=sheet_name, index=False)
        except Exception as e:
            print(f"Error processing {filename}: {e}")
            problematic_files.append(filename)

if problematic_files:
    print("Problematic files:", problematic_files)
else:
    print("All files have been processed successfully.")
# Out:
# All files have been processed successfully.

# %%
import os
import shutil
import pandas as pd
from openpyxl import load_workbook

def extract_pdb_id_from_dockq(filename):
    """Extracts the PDB ID from a DockQ filename."""
    parts = filename.split('_')
    return parts[0]  # PDB ID is the first part

def extract_pdb_id_from_vinardo(filename):
    """Extracts the PDB ID from a vinardo filename."""
    parts = filename.split('_')
    return parts[1]  # PDB ID is after 'vinardo_scoring'

def copy_vinardo_sheets_to_dockq(dockq_dir, vinardo_dir, output_dir):
    if not os.path.exists(output_dir):
        os.makedirs(output_dir)
    
    dockq_files = os.listdir(dockq_dir)
    vinardo_files = os.listdir(vinardo_dir)
    
    # Map vinardo files to their PDB IDs
    vinardo_map = {extract_pdb_id_from_vinardo(f).upper(): f for f in vinardo_files if 'template_based' in f}
    
    for dockq_file in dockq_files:
        if dockq_file.endswith('_TB.xlsx') and 'DockQ_data' in dockq_file:
            pdb_id = extract_pdb_id_from_dockq(dockq_file).upper()
            if pdb_id in vinardo_map:
                dockq_path = os.path.join(dockq_dir, dockq_file)
                vinardo_path = os.path.join(vinardo_dir, vinardo_map[pdb_id])
                output_path = os.path.join(output_dir, dockq_file)
                
                # Copy the DockQ file to the output directory if it's not already there
                if not os.path.exists(output_path):
                    shutil.copyfile(dockq_path, output_path)
                
                print(f"Processing {dockq_file} and {vinardo_map[pdb_id]} for PDB ID {pdb_id}")
                
                vinardo_df = pd.read_excel(vinardo_path, sheet_name='Sheet1')
                
                with pd.ExcelWriter(output_path, engine='openpyxl', mode='a') as writer:
                    book = load_workbook(output_path)
                    writer.book = book
                    if 'Vinardo' in book.sheetnames:
                        std = book['Vinardo']
                        book.remove(std)
                    vinardo_df.to_excel(writer, sheet_name='Vinardo', index=False)
                    
                    print(f'Updated {dockq_file} with Vinardo data for PDB ID {pdb_id}')
            else:
                print(f"No matching Vinardo file found for {dockq_file}")

# Replace these paths with the actual paths to your directories
dockq_dir = '/Users/neginmanshour/Desktop/Protein_Peptide_Evaluation/Data_Evaluation/DockQ/DockQ_Evaluation/DockQ_Analysis/Data/AlphaFold_Multimer_All_TB'
vinardo_dir = '/Users/neginmanshour/Desktop/Protein_Peptide_Evaluation/Autodock_Vina/Data/Vinardo_sorted_TB_alpha_rank'
output_dir = '/Users/neginmanshour/Desktop/Protein_Peptide_Evaluation/Autodock_Vina/Data/vinardo_DockQ_TB'

copy_vinardo_sheets_to_dockq(dockq_dir, vinardo_dir, output_dir)
# Out:
# Processing 8C3H_DockQ_data_TB.xlsx and sorted_8c3h_template_based_vinardo.xlsx for PDB ID 8C3H
# Updated 8C3H_DockQ_data_TB.xlsx with Vinardo data for PDB ID 8C3H
# No matching Vinardo file found for 7QOX_DockQ_data_TB.xlsx
# Processing 8F8Z_DockQ_data_TB.xlsx and sorted_8f8z_template_based_vinardo.xlsx for PDB ID 8F8Z
# Updated 8F8Z_DockQ_data_TB.xlsx with Vinardo data for PDB ID 8F8Z
# No matching Vinardo file found for 8CK5_DockQ_data_TB.xlsx
# Processing 8DGM_DockQ_data_TB.xlsx and sorted_8dgm_template_based_vinardo.xlsx for PDB ID 8DGM
# Updated 8DGM_DockQ_data_TB.xlsx with Vinardo data for PDB ID 8DGM
# Processing 7XV1_DockQ_data_TB.xlsx and sorted_7xv1_template_based_vinardo.xlsx for PDB ID 7XV1
# Updated 7XV1_DockQ_data_TB.xlsx with Vinardo data for PDB ID 7XV1
# Processing 8A68_DockQ_data_TB.xlsx and sorted_8a68_template_based_vinardo.xlsx for PDB ID 8A68
# Updated 8A68_DockQ_data_TB.xlsx with Vinardo data for PDB ID 8A68
# Processing 7ZAX_DockQ_data_TB.xlsx and sorted_7zax_template_based_vinardo.xlsx for PDB ID 7ZAX
# Updated 7ZAX_DockQ_data_TB.xlsx with Vinardo data for PDB ID 7ZAX
# Processing 7UDL_DockQ_data_TB.xlsx and sorted_7udl_template_based_vinardo.xlsx for PDB ID 7UDL
# Updated 7UDL_DockQ_data_TB.xlsx with Vinardo data for PDB ID 7UDL
# Processing 7PRX_DockQ_data_TB.xlsx and sorted_7prx_template_based_vinardo.xlsx for PDB ID 7PRX
# Updated 7PRX_DockQ_data_TB.xlsx with Vinardo data for PDB ID 7PRX
# Processing 7WQQ_DockQ_data_TB.xlsx and sorted_7wqq_template_based_vinardo.xlsx for PDB ID 7WQQ
# Updated 7WQQ_DockQ_data_TB.xlsx with Vinardo data for PDB ID 7WQQ
# Processing 7V1A_DockQ_data_TB.xlsx and sorted_7v1a_template_based_vinardo.xlsx for PDB ID 7V1A
# Updated 7V1A_DockQ_data_TB.xlsx with Vinardo data for PDB ID 7V1A
# Processing 7SXF_DockQ_data_TB.xlsx and sorted_7sxf_template_based_vinardo.xlsx for PDB ID 7SXF
# Updated 7SXF_DockQ_data_TB.xlsx with Vinardo data for PDB ID 7SXF
# Processing 7Z7C_DockQ_data_TB.xlsx and sorted_7z7c_template_based_vinardo.xlsx for PDB ID 7Z7C
# Updated 7Z7C_DockQ_data_TB.xlsx with Vinardo data for PDB ID 7Z7C
# No matching Vinardo file found for 8ESE_DockQ_data_TB.xlsx
# Processing 7XTY_DockQ_data_TB.xlsx and sorted_7xty_template_based_vinardo.xlsx for PDB ID 7XTY
# Updated 7XTY_DockQ_data_TB.xlsx with Vinardo data for PDB ID 7XTY
# Processing 7X8G_DockQ_data_TB.xlsx and sorted_7x8g_template_based_vinardo.xlsx for PDB ID 7X8G
# Updated 7X8G_DockQ_data_TB.xlsx with Vinardo data for PDB ID 7X8G
# Processing 8IA5_DockQ_data_TB.xlsx and sorted_8ia5_template_based_vinardo.xlsx for PDB ID 8IA5
# Updated 8IA5_DockQ_data_TB.xlsx with Vinardo data for PDB ID 8IA5
# Processing 8D7P_DockQ_data_TB.xlsx and sorted_8d7p_template_based_vinardo.xlsx for PDB ID 8D7P
# Updated 8D7P_DockQ_data_TB.xlsx with Vinardo data for PDB ID 8D7P
# No matching Vinardo file found for 8hep_DockQ_data_TB.xlsx
# Processing 7QWV_DockQ_data_TB.xlsx and sorted_7qwv_template_based_vinardo.xlsx for PDB ID 7QWV
# Updated 7QWV_DockQ_data_TB.xlsx with Vinardo data for PDB ID 7QWV
# Processing 8ARE_DockQ_data_TB.xlsx and sorted_8are_template_based_vinardo.xlsx for PDB ID 8ARE
# Updated 8ARE_DockQ_data_TB.xlsx with Vinardo data for PDB ID 8ARE
# Processing 7UI8_DockQ_data_TB.xlsx and sorted_7ui8_template_based_vinardo.xlsx for PDB ID 7UI8
# Updated 7UI8_DockQ_data_TB.xlsx with Vinardo data for PDB ID 7UI8
# Processing 7YUE_DockQ_data_TB.xlsx and sorted_7yue_template_based_vinardo.xlsx for PDB ID 7YUE
# Updated 7YUE_DockQ_data_TB.xlsx with Vinardo data for PDB ID 7YUE
# No matching Vinardo file found for 8HDJ_DockQ_data_TB.xlsx
# Processing 8FK3_DockQ_data_TB.xlsx and sorted_8fk3_template_based_vinardo.xlsx for PDB ID 8FK3
# Updated 8FK3_DockQ_data_TB.xlsx with Vinardo data for PDB ID 8FK3
# Processing 8DWK_DockQ_data_TB.xlsx and sorted_8dwk_template_based_vinardo.xlsx for PDB ID 8DWK
# Updated 8DWK_DockQ_data_TB.xlsx with Vinardo data for PDB ID 8DWK
# Processing 8HLO_DockQ_data_TB.xlsx and sorted_8hlo_template_based_vinardo.xlsx for PDB ID 8HLO
# Updated 8HLO_DockQ_data_TB.xlsx with Vinardo data for PDB ID 8HLO
# Processing 8CIR_DockQ_data_TB.xlsx and sorted_8cir_template_based_vinardo.xlsx for PDB ID 8CIR
# Updated 8CIR_DockQ_data_TB.xlsx with Vinardo data for PDB ID 8CIR
# Processing 8CCW_DockQ_data_TB.xlsx and sorted_8ccw_template_based_vinardo.xlsx for PDB ID 8CCW
# Updated 8CCW_DockQ_data_TB.xlsx with Vinardo data for PDB ID 8CCW
# Processing 7UE2_DockQ_data_TB.xlsx and sorted_7ue2_template_based_vinardo.xlsx for PDB ID 7UE2
# Updated 7UE2_DockQ_data_TB.xlsx with Vinardo data for PDB ID 7UE2
# No matching Vinardo file found for 7ZX4_DockQ_data_TB.xlsx
# Processing 7UW2_DockQ_data_TB.xlsx and sorted_7uw2_template_based_vinardo.xlsx for PDB ID 7UW2
# Updated 7UW2_DockQ_data_TB.xlsx with Vinardo data for PDB ID 7UW2
# Processing 8EBL_DockQ_data_TB.xlsx and sorted_8ebl_template_based_vinardo.xlsx for PDB ID 8EBL
# Updated 8EBL_DockQ_data_TB.xlsx with Vinardo data for PDB ID 8EBL
# Processing 7R2M_DockQ_data_TB.xlsx and sorted_7r2m_template_based_vinardo.xlsx for PDB ID 7R2M
# Updated 7R2M_DockQ_data_TB.xlsx with Vinardo data for PDB ID 7R2M
# Processing 8CZK_DockQ_data_TB.xlsx and sorted_8czk_template_based_vinardo.xlsx for PDB ID 8CZK
# Updated 8CZK_DockQ_data_TB.xlsx with Vinardo data for PDB ID 8CZK
# Processing 7Y9C_DockQ_data_TB.xlsx and sorted_7y9c_template_based_vinardo.xlsx for PDB ID 7Y9C
# Updated 7Y9C_DockQ_data_TB.xlsx with Vinardo data for PDB ID 7Y9C
# Processing 8AFI_DockQ_data_TB.xlsx and sorted_8afi_template_based_vinardo.xlsx for PDB ID 8AFI
# Updated 8AFI_DockQ_data_TB.xlsx with Vinardo data for PDB ID 8AFI
# Processing 8D51_DockQ_data_TB.xlsx and sorted_8d51_template_based_vinardo.xlsx for PDB ID 8D51
# Updated 8D51_DockQ_data_TB.xlsx with Vinardo data for PDB ID 8D51
# Processing 8IA4_DockQ_data_TB.xlsx and sorted_8ia4_template_based_vinardo.xlsx for PDB ID 8IA4
# Updated 8IA4_DockQ_data_TB.xlsx with Vinardo data for PDB ID 8IA4
# Processing 7UDK_DockQ_data_TB.xlsx and sorted_7udk_template_based_vinardo.xlsx for PDB ID 7UDK
# Updated 7UDK_DockQ_data_TB.xlsx with Vinardo data for PDB ID 7UDK
# Processing 8FXQ_DockQ_data_TB.xlsx and sorted_8fxq_template_based_vinardo.xlsx for PDB ID 8FXQ
# Updated 8FXQ_DockQ_data_TB.xlsx with Vinardo data for PDB ID 8FXQ
# Processing 8EQ5_DockQ_data_TB.xlsx and sorted_8eq5_template_based_vinardo.xlsx for PDB ID 8EQ5
# Updated 8EQ5_DockQ_data_TB.xlsx with Vinardo data for PDB ID 8EQ5
# No matching Vinardo file found for 8OEP_DockQ_data_TB.xlsx
# No matching Vinardo file found for 8I3G_DockQ_data_TB.xlsx
# Processing 8BFT_DockQ_data_TB.xlsx and sorted_8bft_template_based_vinardo.xlsx for PDB ID 8BFT
# Updated 8BFT_DockQ_data_TB.xlsx with Vinardo data for PDB ID 8BFT
# Processing 8AHS_DockQ_data_TB.xlsx and sorted_8ahs_template_based_vinardo.xlsx for PDB ID 8AHS
# Updated 8AHS_DockQ_data_TB.xlsx with Vinardo data for PDB ID 8AHS
# No matching Vinardo file found for 7SXJ_DockQ_data_TB.xlsx
# Processing 7Z6U_DockQ_data_TB.xlsx and sorted_7z6u_template_based_vinardo.xlsx for PDB ID 7Z6U
# Updated 7Z6U_DockQ_data_TB.xlsx with Vinardo data for PDB ID 7Z6U
# Processing 8C2P_DockQ_data_TB.xlsx and sorted_8c2p_template_based_vinardo.xlsx for PDB ID 8C2P
# Updated 8C2P_DockQ_data_TB.xlsx with Vinardo data for PDB ID 8C2P
# Processing 8CZ9_DockQ_data_TB.xlsx and sorted_8cz9_template_based_vinardo.xlsx for PDB ID 8CZ9
# Updated 8CZ9_DockQ_data_TB.xlsx with Vinardo data for PDB ID 8CZ9
# Processing 7Y8F_DockQ_data_TB.xlsx and sorted_7y8f_template_based_vinardo.xlsx for PDB ID 7Y8F
# Updated 7Y8F_DockQ_data_TB.xlsx with Vinardo data for PDB ID 7Y8F
# Processing 8DVL_DockQ_data_TB.xlsx and sorted_8dvl_template_based_vinardo.xlsx for PDB ID 8DVL
# Updated 8DVL_DockQ_data_TB.xlsx with Vinardo data for PDB ID 8DVL
# Processing 8BR9_DockQ_data_TB.xlsx and sorted_8br9_template_based_vinardo.xlsx for PDB ID 8BR9
# Updated 8BR9_DockQ_data_TB.xlsx with Vinardo data for PDB ID 8BR9
# Processing 7TO9_DockQ_data_TB.xlsx and sorted_7to9_template_based_vinardo.xlsx for PDB ID 7TO9
# Updated 7TO9_DockQ_data_TB.xlsx with Vinardo data for PDB ID 7TO9
# Processing 7XFG_DockQ_data_TB.xlsx and sorted_7xfg_template_based_vinardo.xlsx for PDB ID 7XFG
# Updated 7XFG_DockQ_data_TB.xlsx with Vinardo data for PDB ID 7XFG
# Processing 7SQA_DockQ_data_TB.xlsx and sorted_7sqa_template_based_vinardo.xlsx for PDB ID 7SQA
# Updated 7SQA_DockQ_data_TB.xlsx with Vinardo data for PDB ID 7SQA
# Processing 7Z5L_DockQ_data_TB.xlsx and sorted_7z5l_template_based_vinardo.xlsx for PDB ID 7Z5L
# Updated 7Z5L_DockQ_data_TB.xlsx with Vinardo data for PDB ID 7Z5L
# Processing 8B58_DockQ_data_TB.xlsx and sorted_8b58_template_based_vinardo.xlsx for PDB ID 8B58
# Updated 8B58_DockQ_data_TB.xlsx with Vinardo data for PDB ID 8B58
# Processing 7ZW4_DockQ_data_TB.xlsx and sorted_7zw4_template_based_vinardo.xlsx for PDB ID 7ZW4
# Updated 7ZW4_DockQ_data_TB.xlsx with Vinardo data for PDB ID 7ZW4

# %%
import os
import pandas as pd
import matplotlib.pyplot as plt
from scipy.stats import spearmanr
from zipfile import BadZipFile

def process_excel_files(directory_path, output_directory):
    excel_files = [f for f in os.listdir(directory_path) if f.endswith('.xlsx')]
    correlations = []  # To store file names and their Spearman correlations
    
    for excel_file in excel_files:
        excel_file_path = os.path.join(directory_path, excel_file)
        
        try:
            xls = pd.ExcelFile(excel_file_path)
        except BadZipFile:
            print(f'Error: The file "{excel_file}" is not a valid Excel file or is corrupted.')
            continue
        except Exception as e:
            print(f'An unexpected error occurred while processing {excel_file}: {e}')
            continue
        
        if 'Vinardo' not in xls.sheet_names:
            print(f'The file "{excel_file}" does not contain a "Vinardo" sheet.')
            continue

        dockq_df = pd.read_excel(excel_file_path, sheet_name='Sheet')
        pyrosetta_df = pd.read_excel(excel_file_path, sheet_name='Vinardo')
        
        pyrosetta_rank_column = 'vinardo_rank'
        alpha_to_dockq_map = dockq_df.set_index('AlphaFold Rank')['DockQ Rank'].to_dict()
        pyrosetta_df['DockQ Rank'] = pyrosetta_df['alphafold rank'].map(alpha_to_dockq_map)
        
        filtered_pyrosetta_df = pyrosetta_df.dropna(subset=['DockQ Rank'])
        
        spearman_corr, _ = spearmanr(filtered_pyrosetta_df[pyrosetta_rank_column], filtered_pyrosetta_df['DockQ Rank'])
        
        plt.figure(figsize=(10, 6))
        plt.scatter(filtered_pyrosetta_df['DockQ Rank'], filtered_pyrosetta_df[pyrosetta_rank_column], alpha=0.6)
        plt.title(f'File: {excel_file}\nSpearman Correlation: {spearman_corr:.2f}')
        plt.xlabel('DockQ Rank')
        plt.ylabel('vinardo_rank')
        plt.grid(True)
        plt.show()

        # Append file name and Spearman correlation to the list
        correlations.append({'File Name': excel_file, 'Spearman Correlation': spearman_corr})
        print(f'File: {excel_file}\nSpearman Correlation Coefficient: {spearman_corr}\n')
    
    # Convert list to DataFrame
    correlations_df = pd.DataFrame(correlations)
    
    # Ensure the output directory exists
    if not os.path.exists(output_directory):
        os.makedirs(output_directory)
    
    # Path for the new Excel file
    output_file_path = os.path.join(output_directory, 'correlations_vinardo_TB.xlsx')
    
    # Save DataFrame to an Excel file
    correlations_df.to_excel(output_file_path, index=False)
    print(f'Summary of Spearman correlations saved to {output_file_path}')

# Example usage
directory_path = '/Users/neginmanshour/Desktop/Protein_Peptide_Evaluation/Autodock_Vina/Data/vinardo_DockQ_TB'
output_directory = '/Users/neginmanshour/Desktop/Protein_Peptide_Evaluation/spearman_Correlation/TB_Spearman'
process_excel_files(directory_path, output_directory)
# Out:
# File: 8C3H_DockQ_data_TB.xlsx
# Spearman Correlation Coefficient: 0.26779674379674384
# File: 8F8Z_DockQ_data_TB.xlsx
# Spearman Correlation Coefficient: 0.2319118959118959
# File: 8DGM_DockQ_data_TB.xlsx
# Spearman Correlation Coefficient: 0.11111925911925913
# File: 7XV1_DockQ_data_TB.xlsx
# Spearman Correlation Coefficient: 0.48923841323841327
# File: 8A68_DockQ_data_TB.xlsx
# Spearman Correlation Coefficient: -0.25191088791088795
# File: 7ZAX_DockQ_data_TB.xlsx
# Spearman Correlation Coefficient: -0.5102285893107535
# File: 7UDL_DockQ_data_TB.xlsx
# Spearman Correlation Coefficient: -0.25815631262525046
# File: 7PRX_DockQ_data_TB.xlsx
# Spearman Correlation Coefficient: -0.4246404400392375
# File: 7WQQ_DockQ_data_TB.xlsx
# Spearman Correlation Coefficient: 0.45889648365800667
# File: 7V1A_DockQ_data_TB.xlsx
# Spearman Correlation Coefficient: 0.17655943719270367
# File: 7SXF_DockQ_data_TB.xlsx
# Spearman Correlation Coefficient: 0.8609286561110207
# File: 7Z7C_DockQ_data_TB.xlsx
# Spearman Correlation Coefficient: 0.19165061654841212
# File: 7XTY_DockQ_data_TB.xlsx
# Spearman Correlation Coefficient: 0.5117574367955129
# File: 7X8G_DockQ_data_TB.xlsx
# Spearman Correlation Coefficient: -0.8166234330522907
# File: 8IA5_DockQ_data_TB.xlsx
# Spearman Correlation Coefficient: -0.28573182973182976
# File: 8D7P_DockQ_data_TB.xlsx
# Spearman Correlation Coefficient: -0.10972054972054973
# File: 7QWV_DockQ_data_TB.xlsx
# Spearman Correlation Coefficient: 0.4884637623595538
# File: 8ARE_DockQ_data_TB.xlsx
# Spearman Correlation Coefficient: -0.44711319911319913
# File: 7UI8_DockQ_data_TB.xlsx
# Spearman Correlation Coefficient: -0.18834401535804338
# File: 7YUE_DockQ_data_TB.xlsx
# Spearman Correlation Coefficient: -0.5781926134551384
# File: 8FK3_DockQ_data_TB.xlsx
# Spearman Correlation Coefficient: 0.15366633366633367
# File: 8DWK_DockQ_data_TB.xlsx
# Spearman Correlation Coefficient: -0.02599876999877
# File: 8HLO_DockQ_data_TB.xlsx
# Spearman Correlation Coefficient: -0.04218517515511503
# File: 8CIR_DockQ_data_TB.xlsx
# Spearman Correlation Coefficient: -0.4567291447291448
# File: 8CCW_DockQ_data_TB.xlsx
# Spearman Correlation Coefficient: -0.25275975675975676
# File: 7UE2_DockQ_data_TB.xlsx
# Spearman Correlation Coefficient: -0.4182427918900864
# File: 7UW2_DockQ_data_TB.xlsx
# Spearman Correlation Coefficient: 0.1231266135875354
# File: 8EBL_DockQ_data_TB.xlsx
# Spearman Correlation Coefficient: -0.21305412905412907
# File: 7R2M_DockQ_data_TB.xlsx
# Spearman Correlation Coefficient: -0.5213272190025696
# File: 8CZK_DockQ_data_TB.xlsx
# Spearman Correlation Coefficient: -0.01415042615042615
# File: 7Y9C_DockQ_data_TB.xlsx
# Spearman Correlation Coefficient: -0.5277021550608725
# File: 8AFI_DockQ_data_TB.xlsx
# Spearman Correlation Coefficient: -0.3632384672384672
# File: 8D51_DockQ_data_TB.xlsx
# Spearman Correlation Coefficient: 0.5560913680913682
# File: 8IA4_DockQ_data_TB.xlsx
# Spearman Correlation Coefficient: -0.5242850482850483
# File: 7UDK_DockQ_data_TB.xlsx
# Spearman Correlation Coefficient: -0.4220021905673208
# File: 8FXQ_DockQ_data_TB.xlsx
# Spearman Correlation Coefficient: 0.08964437364437365
# File: 8EQ5_DockQ_data_TB.xlsx
# Spearman Correlation Coefficient: -0.0528029808029808
# File: 8BFT_DockQ_data_TB.xlsx
# Spearman Correlation Coefficient: -0.5415036735036736
# File: 8AHS_DockQ_data_TB.xlsx
# Spearman Correlation Coefficient: -0.5401068481068482
# File: 7Z6U_DockQ_data_TB.xlsx
# Spearman Correlation Coefficient: 0.053038340946156566
# File: 8C2P_DockQ_data_TB.xlsx
# Spearman Correlation Coefficient: -0.696904152904153
# File: 8CZ9_DockQ_data_TB.xlsx
# Spearman Correlation Coefficient: 0.007527103527103527
# File: 7Y8F_DockQ_data_TB.xlsx
# Spearman Correlation Coefficient: 0.29597887667226336
# File: 8DVL_DockQ_data_TB.xlsx
# Spearman Correlation Coefficient: -0.4191007191007191
# File: 8BR9_DockQ_data_TB.xlsx
# Spearman Correlation Coefficient: -0.23221102021102022
# File: 7TO9_DockQ_data_TB.xlsx
# Spearman Correlation Coefficient: 0.10330822606173305
# File: 7XFG_DockQ_data_TB.xlsx
# Spearman Correlation Coefficient: 0.7877765621332755
# File: 7SQA_DockQ_data_TB.xlsx
# Spearman Correlation Coefficient: 0.3681875961875962
# File: 7Z5L_DockQ_data_TB.xlsx
# Spearman Correlation Coefficient: 0.37019009819009824
# File: 8B58_DockQ_data_TB.xlsx
# Spearman Correlation Coefficient: 0.7216012576012577
# File: 7ZW4_DockQ_data_TB.xlsx
# Spearman Correlation Coefficient: -0.5434459114459115
#
# Summary of Spearman correlations saved to /Users/neginmanshour/Desktop/Protein_Peptide_Evaluation/spearman_Correlation/TB_Spearman/correlations_vinardo_TB.xlsx

# %%
import pandas as pd

def calculate_positive_negative_percentages(file_path):
    # Load the Excel file
    data = pd.read_excel(file_path)
    
    # Count the total number of entries
    total_entries = len(data['Spearman Correlation'])
    
    # Count the number of positive and negative Pyros_Spearman Correlation values
    positive_count = data[data['Spearman Correlation'] > 0].shape[0]
    negative_count = data[data['Spearman Correlation'] < 0].shape[0]
    
    # Calculate percentages
    positive_percentage = (positive_count / total_entries) * 100
    negative_percentage = (negative_count / total_entries) * 100
    
    return positive_percentage, negative_percentage

# Example usage
file_path = '/Users/neginmanshour/Desktop/Protein_Peptide_Evaluation/spearman_Correlation/TB_Spearman/correlations_vinardo_TB.xlsx'  # Replace with the actual path to your Excel file
positive_percentage, negative_percentage = calculate_positive_negative_percentages(file_path)
print(f"Positive Vinardo_Spearman Correlation: {positive_percentage:.2f}%")
print(f"Negative Vinardo_Spearman Correlation: {negative_percentage:.2f}%")
# Out:
# Positive Vinardo_Spearman Correlation: 43.14%
# Negative Vinardo_Spearman Correlation: 56.86%

# %%
import os
import pandas as pd

# Directory containing the Excel files
directory_path = '/Users/neginmanshour/Desktop/Protein_Peptide_Evaluation/Autodock_Vina/Data/vinardo_DockQ_TB'

# Initialize a list to store the results
results = []

# List all Excel files in the directory
excel_files = [file for file in os.listdir(directory_path) if file.endswith('.xlsx')]

for file_name in excel_files:
    file_path = os.path.join(directory_path, file_name)
    xls = pd.ExcelFile(file_path)

    # Extract pdb_id from file name
    pdb_id = file_name.split('_')[0]

    # Load data from "Foldx" sheet
    foldx_df = pd.read_excel(file_path, sheet_name='Vinardo')
    #structure_name_for_rank_zero = foldx_df[foldx_df['vinardo_rank'] == 0]['file'].iloc[0].replace('_clean.pdb', '')
    structure_name_for_rank_zero = foldx_df[foldx_df['vinardo_rank'] == 0]['file'].iloc[0].replace('.pdb', '.pdb_clean')

    # Load data from "Sheet" sheet
    sheet_df = pd.read_excel(file_path, sheet_name='Sheet')

    # Highest DockQ score
    highest_dockq_score = sheet_df['DockQ'].max()

    # DockQ score for the structure from Foldx
    highest_foldx_dockq_score = sheet_df[sheet_df['File Name'].str.contains(structure_name_for_rank_zero)]['DockQ'].max()

    # Calculate Loss
    score_Loss = highest_dockq_score - highest_foldx_dockq_score

    # Append results
    results.append([pdb_id, highest_dockq_score, highest_foldx_dockq_score, score_Loss])

# Create a DataFrame from the results
results_df = pd.DataFrame(results, columns=['File Name', 'DockQ', 'Vinardo ranked', 'Loss'])

# Save the results into a new Excel file
output_path = '/Users/neginmanshour/Desktop/Protein_Peptide_Evaluation/Loss/TB_Loss/Vinardo_loss_TB.xlsx'
results_df.to_excel(output_path, index=False)

print(f"Results have been saved to {output_path}")
# Out:
# Results have been saved to /Users/neginmanshour/Desktop/Protein_Peptide_Evaluation/Loss/TB_Loss/Vinardo_loss_TB.xlsx
