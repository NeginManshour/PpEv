# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Data for plotting
software_names = ['AlphaFold-Multimer', 'Pyrosetta', 'Foldx/Stability', 'Foldx/Interaction', 'Haddock/emscore', 'Haddock/mdscore', 'GNN-Dove', 'Vina', 'Vinardo', 'Deep_GNN_esm', 'Interpeprank']
percentages = [55.00, 51.67, 50.00, 40, 60.00, 68.33, 55.93, 39.29, 44.64, 70.0, 56.82]

# Creating the bar chart with percentage values above each bar, all bars have the same color, and larger font size for labels
plt.figure(figsize=(12, 8))
bars = sns.barplot(x=software_names, y=percentages, color="blue")  # All bars with the same color

# Adding percentage values above each bar with larger font size
for bar in bars.patches:
    # Formatting the label
    label = f'{bar.get_height():.2f}%'
    
    # Positioning the label above the bar with larger font size
    plt.text(bar.get_x() + bar.get_width() / 2, bar.get_height(), label, ha='center', va='bottom', fontsize=15)

plt.title('Positive Spearman Correlations in Template-Based Models', fontsize=20)
plt.ylabel('Percentage (%)', fontsize=18)
#plt.xlabel('Software', fontsize=16)
plt.yticks(fontsize=16)
plt.xticks(rotation=90, fontsize=14)  # Rotates labels to 45 degrees for better readability
plt.ylim(0, 100)  # Ensures there is space above the bars for the labels
plt.grid(axis='y')

plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Data for plotting
software_names = ['AlphaFold-Multimer', 'Pyrosetta', 'Foldx/Stability', 'Foldx/Interaction', 'Haddock/emscore', 'Haddock/mdscore', 'GNN-Dove', 'Vina', 'Vinardo', 'Deep_GNN_esm', 'Interpeprank']
percentages = [55.00, 51.67, 50.00, 40, 60.00, 68.33, 55.93, 39.29, 44.64, 70.0, 56.82]

# Creating the bar chart with percentage values above each bar, all bars have the same color, and larger font size for labels
plt.figure(figsize=(12, 8))
bars = sns.barplot(x=software_names, y=percentages, color="blue")  # All bars with the same color

# Adding percentage values above each bar with larger font size
for bar in bars.patches:
    # Formatting the label
    label = f'{bar.get_height():.2f}%'
    
    # Positioning the label above the bar with larger font size
    plt.text(bar.get_x() + bar.get_width() / 2, bar.get_height(), label, ha='center', va='bottom', fontsize=15)

plt.title('Positive Spearman Correlations in Template-Based Models', fontsize=20, fontweight='bold', pad=20)
plt.ylabel('Percentage (%)', fontsize=18)
#plt.xlabel('Software', fontsize=16)
plt.yticks(fontsize=16)
plt.xticks(rotation=90, fontsize=14)  # Rotates labels to 45 degrees for better readability
plt.ylim(0, 100)  # Ensures there is space above the bars for the labels
plt.grid(axis='y')

# Save the figure with 1000 DPI
output_directory = '/Users/neginmanshour/Desktop/Protein_Peptide_Evaluation/spearman_Correlation/Figures/positive_TB.png'  # Specify your output directory here
plt.savefig(output_directory, dpi=1000)  # Saves the figure with the specified DPI

plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Data for plotting
software_names = ['AF-Score', 'PyRosetta', 'FoldX-Stability', 'FoldX-Interaction', 'HADDOCK-emscore', 'HADDOCK-mdscore', 'GNN_Dove', 'Vina', 'Vinardo', 'DeepRank-GNN-esm']
percentages = [55.00, 51.67, 49.15, 38.98, 60.00, 68.33, 55.93, 39.29, 44.64, 70.0]

# Creating the bar chart with percentage values above each bar, all bars have the same color, and larger font size for labels
plt.figure(figsize=(12, 8), facecolor='white')  # Set the background to white
bars = sns.barplot(x=software_names, y=percentages, color="blue")  # All bars with the same color

# Adding percentage values above each bar with larger font size
for bar in bars.patches:
    # Formatting the label
    label = f'{bar.get_height():.2f}%'
    
    # Positioning the label above the bar with larger font size
    plt.text(bar.get_x() + bar.get_width() / 2, bar.get_height(), label, ha='center', va='bottom', fontsize=15)

plt.title('Positive Spearman Correlations in Template-Based Models', fontsize=20, fontweight='bold', pad=20)
plt.ylabel('Percentage (%)', fontsize=18)
#plt.xlabel('Software', fontsize=16)
plt.yticks(fontsize=16)
plt.xticks(rotation=90, fontsize=14)  # Rotates labels to 45 degrees for better readability
plt.ylim(0, 100)  # Ensures there is space above the bars for the labels
plt.grid(axis='y')

# Save the figure with 1000 DPI and ensure the entire content is included
output_directory = '/Users/neginmanshour/Desktop/Protein_Peptide_Evaluation/spearman_Correlation/Figures/positive_TB.png'  # Specify your output directory here
plt.savefig(output_directory, dpi=1000, bbox_inches='tight', facecolor='white')  # Saves the figure with the specified DPI, tight bounding box, and white background

plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Data for plotting
software_names = ['AlphaFold-Multimer', 'Pyrosetta', 'Foldx/Stability', 'Foldx/Interaction', 'Haddock/emscore', 'Haddock/mdscore', 'GNN-Dove', 'Vina', 'VInardo', 'Deep_GNN_esm', 'Interpeprank']
percentages = [63.33, 56.67, 56.67, 51.67, 56.67, 56.67, 67.8, 50, 41.07, 60.00, 52.94]

# Creating the bar chart with percentage values above each bar, all bars have the same color, and larger font size for labels
plt.figure(figsize=(12, 8))
bars = sns.barplot(x=software_names, y=percentages, color="brown")  # All bars with the same color

# Adding percentage values above each bar with larger font size
for bar in bars.patches:
    # Formatting the label
    label = f'{bar.get_height():.2f}%'
    
    # Positioning the label above the bar with larger font size
    plt.text(bar.get_x() + bar.get_width() / 2, bar.get_height(), label, ha='center', va='bottom', fontsize=15)

plt.title('Positive Spearman Correlations in Template-Free Models', fontsize=20)
plt.ylabel('Percentage (%)', fontsize=18)
#plt.xlabel('Software', fontsize=16)
plt.yticks(fontsize=16)
plt.xticks(rotation=90, fontsize=14)  # Rotates labels to 45 degrees for better readability
plt.ylim(0, 100)  # Ensures there is space above the bars for the labels
plt.grid(axis='y')

plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Data for plotting
software_names = ['AlphaFold-Multimer', 'Pyrosetta', 'Foldx/Stability', 'Foldx/Interaction', 'Haddock/emscore', 'Haddock/mdscore', 'GNN-Dove', 'Vina', 'Vinardo', 'Deep_GNN_esm', 'Interpeprank']
percentages = [63.33, 56.67, 56.67, 51.67, 56.67, 56.67, 67.8, 50, 41.07, 60.00, 52.94]

# Creating the bar chart with percentage values above each bar, all bars have the same color, and larger font size for labels
plt.figure(figsize=(12, 8))
bars = sns.barplot(x=software_names, y=percentages, color="brown")  # All bars with the same color

# Adding percentage values above each bar with larger font size
for bar in bars.patches:
    # Formatting the label
    label = f'{bar.get_height():.2f}%'
    
    # Positioning the label above the bar with larger font size
    plt.text(bar.get_x() + bar.get_width() / 2, bar.get_height(), label, ha='center', va='bottom', fontsize=15)

plt.title('Positive Spearman Correlations in Template-Free Models', fontsize=20, fontweight='bold', pad=20)
plt.ylabel('Percentage (%)', fontsize=18)
#plt.xlabel('Software', fontsize=16)
plt.yticks(fontsize=16)
plt.xticks(rotation=90, fontsize=14)  # Rotates labels to 45 degrees for better readability
plt.ylim(0, 100)  # Ensures there is space above the bars for the labels
plt.grid(axis='y')

# Save the figure with 1000 DPI
output_directory = '/Users/neginmanshour/Desktop/Protein_Peptide_Evaluation/spearman_Correlation/Figures/positive_TF.png'   # Specify your output directory here
plt.savefig(output_directory, dpi=1000)  # Saves the figure with the specified DPI

plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Data for plotting
software_names = ['AF-Score', 'PyRosetta', 'FoldX-Stability', 'FoldX-Interaction', 'HADDOCK-emscore', 'HADDOCK-mdscore', 'GNN_Dove', 'Vina', 'Vinardo', 'DeepRank-GNN-esm']
percentages = [63.33, 56.67, 56.67, 51.67, 56.67, 56.67, 67.8, 50, 41.07, 60.00]

# Creating the bar chart with percentage values above each bar, all bars have the same color, and larger font size for labels
plt.figure(figsize=(12, 8), facecolor='white')  # Set the background to white
bars = sns.barplot(x=software_names, y=percentages, color="brown")  # All bars with the same color

# Adding percentage values above each bar with larger font size
for bar in bars.patches:
    # Formatting the label
    label = f'{bar.get_height():.2f}%'
    
    # Positioning the label above the bar with larger font size
    plt.text(bar.get_x() + bar.get_width() / 2, bar.get_height(), label, ha='center', va='bottom', fontsize=15)

plt.title('Positive Spearman Correlations in Template-Free Models', fontsize=20, fontweight='bold', pad=20)
plt.ylabel('Percentage (%)', fontsize=18, fontweight='bold')
#plt.xlabel('Software', fontsize=16)
plt.yticks(fontsize=16)
plt.xticks(rotation=90, fontsize=14)  # Rotates labels to 45 degrees for better readability
plt.ylim(0, 100)  # Ensures there is space above the bars for the labels
plt.grid(axis='y')

# Save the figure with 1000 DPI and ensure the entire content is included
output_directory = '/Users/neginmanshour/Desktop/Protein_Peptide_Evaluation/spearman_Correlation/Figures/positive_TF.png'
plt.savefig(output_directory, dpi=1000, bbox_inches='tight')  # Saves the figure with the specified DPI and tight bounding box

plt.show()
