# %%
import json

# Load configuration and define a global variable
def load_config():
    global config
    with open('config_Distributions.json') as config_file:
        config = json.load(config_file)

# Call the function to load the configuration
load_config()

# %%
import pandas as pd
import os
import matplotlib.pyplot as plt
import seaborn as sns
import json

# Load configuration and define a global variable
def load_config():
    global config
    with open('config_Distributions.json') as config_file:
        config = json.load(config_file)

# Call the function to load the configuration
load_config()

# Define the directories for each category from the configuration file
directories = {
    'Molprobity_TB': os.path.join(config["First_ranked_MolProbity"], 'AFM-TB.xlsx'),
    'Molprobity_TF': os.path.join(config["First_ranked_MolProbity"], 'AFM-TF.xlsx'),
    'Colab_Mol_TB': os.path.join(config["First_ranked_MolProbity"], 'CF-TB.xlsx'),
    'Colab_Mol_TF': os.path.join(config["First_ranked_MolProbity"], 'CF-TF.xlsx'),
    'AF3': os.path.join(config["First_ranked_MolProbity"], 'AF3.xlsx'),
    'Native_Molprobity_TF': os.path.join(config["First_ranked_MolProbity"], 'GT.xlsx')
}

# List to store individual DataFrames for each category
category_dfs = {cat: [] for cat in directories}

# Loop through all files in each directory
for category, file_path in directories.items():
    df = pd.read_excel(file_path)
    df['Category'] = category
    category_dfs[category] = df

# Combine DataFrames for each category
combined_df = pd.concat(category_dfs.values(), ignore_index=True)

# Ensure the relevant columns are numeric
parameters = ['Rama_Z_whole', 'Rama_Z_helix', 'Rama_Z_sheet', 'Rama_Z_loop', 'Clashscore']
for param in parameters:
    combined_df[param] = pd.to_numeric(combined_df[param], errors='coerce')

# Define the new names for categories
category_order_renamed = ['AFM-TB', 'AFM-TF', 'CF-TB', 'CF-TF', 'AF3', 'GT']
category_mapping = {
    'Molprobity_TB': 'AFM-TB',
    'Molprobity_TF': 'AFM-TF',
    'Colab_Mol_TB': 'CF-TB',
    'Colab_Mol_TF': 'CF-TF',
    'AF3': 'AF3',
    'Native_Molprobity_TF': 'GT'
}

# Updating the category names in the DataFrame
combined_df['Category'] = combined_df['Category'].map(category_mapping)

# Set font sizes for each part of the plot
def plot_box_plots(output_directory, title_fontsize=22, xlabel_fontsize=20, ylabel_fontsize=20, xticks_fontsize=18, yticks_fontsize=20):
    plot_colors = ['lightgreen', 'lightblue', 'lightcoral', 'lightpink', 'lightyellow', 'lightgrey']
    
    # Create the output directory if it doesn't exist
    if not os.path.exists(output_directory):
        os.makedirs(output_directory)

    # Plotting boxplots for each parameter
    for i, (param, color) in enumerate(zip(parameters, plot_colors), start=8):  # Start naming from Fig_S8
        plt.figure(figsize=(12, 8))

        # Drop rows with NaN values in the parameter column
        df_to_plot = combined_df.dropna(subset=[param])

        # Creating the boxplot with specified order and new names
        box = sns.boxplot(x='Category', y=param, data=df_to_plot, order=category_order_renamed, palette=[color])

        # Change the color of the median line to red
        for line in box.lines:
            # Lines 4n+2 (n=0,1,2,...) are the median lines
            if box.lines.index(line) % 6 == 4:
                line.set_color('red')
                line.set_linewidth(2)

        plt.title(f'Distribution of {param} (First-Ranked models)', fontsize=title_fontsize)
        plt.xlabel('', fontsize=0)  # Hide the x-axis label
        plt.ylabel(param, fontsize=ylabel_fontsize)
        plt.xticks(fontsize=xticks_fontsize, rotation=45)
        plt.yticks(fontsize=yticks_fontsize)
        plt.grid(True)

        # Save the plot as a JPEG image with dpi 1000
        plot_path = os.path.join(output_directory, f'Fig_S{i}.jpeg')
        plt.savefig(plot_path, dpi=1000, format='jpeg', bbox_inches='tight')

        # Display the plot
        plt.show()

        # Print statistics for each category and parameter
        print(f"Statistics for {param}:")
        for category in category_order_renamed:
            data = df_to_plot[df_to_plot['Category'] == category][param].dropna()
            median = data.median()
            q1 = data.quantile(0.25)
            q3 = data.quantile(0.75)
            iqr = q3 - q1
            minimum = data.min()
            maximum = data.max()
            spread = maximum - minimum
            print(f"{category}:")
            print(f"  Median: {median}")
            print(f"  Q1 (25th percentile): {q1}")
            print(f"  Q3 (75th percentile): {q3}")
            print(f"  IQR: {iqr}")
            print(f"  Minimum: {minimum}")
            print(f"  Maximum: {maximum}")
            print(f"  Spread: {spread}")
        print("\n")

# Usage example
output_directory = config["Supp_Figures_directory"]
plot_box_plots(output_directory, title_fontsize=22, xlabel_fontsize=20, ylabel_fontsize=20, xticks_fontsize=18, yticks_fontsize=20)
# Out:
# Statistics for Rama_Z_whole:
# AFM-TB:
#   Median: 0.47
#   Q1 (25th percentile): -0.0175
#   Q3 (75th percentile): 1.5675
#   IQR: 1.585
#   Minimum: -2.01
#   Maximum: 4.18
#   Spread: 6.1899999999999995
# AFM-TF:
#   Median: 0.535
#   Q1 (25th percentile): -0.035
#   Q3 (75th percentile): 1.51
#   IQR: 1.545
#   Minimum: -2.43
#   Maximum: 4.2
#   Spread: 6.630000000000001
# CF-TB:
#   Median: 0.54
#   Q1 (25th percentile): -0.0425
#   Q3 (75th percentile): 1.6125
#   IQR: 1.655
#   Minimum: -2.76
#   Maximum: 3.92
#   Spread: 6.68
# CF-TF:
#   Median: 0.53
#   Q1 (25th percentile): -0.20750000000000002
#   Q3 (75th percentile): 1.435
#   IQR: 1.6425
#   Minimum: -3.38
#   Maximum: 3.99
#   Spread: 7.37
# AF3:
#   Median: 0.55
#   Q1 (25th percentile): -0.12000000000000001
#   Q3 (75th percentile): 1.7349999999999999
#   IQR: 1.855
#   Minimum: -1.21
#   Maximum: 5.54
#   Spread: 6.75
# GT:
#   Median: -0.56
#   Q1 (25th percentile): -1.07
#   Q3 (75th percentile): 0.14
#   IQR: 1.21
#   Minimum: -3.46
#   Maximum: 3.22
#   Spread: 6.68
# Statistics for Rama_Z_helix:
# AFM-TB:
#   Median: 0.66
#   Q1 (25th percentile): 0.315
#   Q3 (75th percentile): 1.545
#   IQR: 1.23
#   Minimum: -3.16
#   Maximum: 2.67
#   Spread: 5.83
# AFM-TF:
#   Median: 0.715
#   Q1 (25th percentile): 0.0775
#   Q3 (75th percentile): 1.5275
#   IQR: 1.4500000000000002
#   Minimum: -4.44
#   Maximum: 2.7
#   Spread: 7.140000000000001
# CF-TB:
#   Median: 0.65
#   Q1 (25th percentile): 0.15
#   Q3 (75th percentile): 1.375
#   IQR: 1.225
#   Minimum: -2.93
#   Maximum: 2.83
#   Spread: 5.76
# CF-TF:
#   Median: 0.72
#   Q1 (25th percentile): 0.11499999999999999
#   Q3 (75th percentile): 1.325
#   IQR: 1.21
#   Minimum: -2.62
#   Maximum: 2.63
#   Spread: 5.25
# AF3:
#   Median: 0.46499999999999997
#   Q1 (25th percentile): 0.03
#   Q3 (75th percentile): 1.2825
#   IQR: 1.2525
#   Minimum: -4.17
#   Maximum: 3.79
#   Spread: 7.96
# GT:
#   Median: -0.61
#   Q1 (25th percentile): -1.01
#   Q3 (75th percentile): -0.01
#   IQR: 1.0
#   Minimum: -5.0
#   Maximum: 2.08
#   Spread: 7.08
# Statistics for Rama_Z_sheet:
# AFM-TB:
#   Median: 0.26
#   Q1 (25th percentile): -0.235
#   Q3 (75th percentile): 1.56
#   IQR: 1.795
#   Minimum: -1.37
#   Maximum: 2.85
#   Spread: 4.220000000000001
# AFM-TF:
#   Median: 0.34
#   Q1 (25th percentile): -0.05500000000000001
#   Q3 (75th percentile): 1.54
#   IQR: 1.595
#   Minimum: -4.06
#   Maximum: 2.89
#   Spread: 6.949999999999999
# CF-TB:
#   Median: 0.21
#   Q1 (25th percentile): 0.045
#   Q3 (75th percentile): 1.5125
#   IQR: 1.4675
#   Minimum: -1.2
#   Maximum: 3.21
#   Spread: 4.41
# CF-TF:
#   Median: 0.45999999999999996
#   Q1 (25th percentile): -0.0325
#   Q3 (75th percentile): 1.4575
#   IQR: 1.49
#   Minimum: -1.62
#   Maximum: 3.03
#   Spread: 4.65
# AF3:
#   Median: 0.12
#   Q1 (25th percentile): -0.42
#   Q3 (75th percentile): 1.16
#   IQR: 1.5799999999999998
#   Minimum: -1.69
#   Maximum: 3.14
#   Spread: 4.83
# GT:
#   Median: -0.045
#   Q1 (25th percentile): -0.5275000000000001
#   Q3 (75th percentile): 0.955
#   IQR: 1.4825
#   Minimum: -2.9
#   Maximum: 2.09
#   Spread: 4.99
# Statistics for Rama_Z_loop:
# AFM-TB:
#   Median: 0.08499999999999999
#   Q1 (25th percentile): -0.64
#   Q3 (75th percentile): 0.6
#   IQR: 1.24
#   Minimum: -2.76
#   Maximum: 5.57
#   Spread: 8.33
# AFM-TF:
#   Median: 0.1
#   Q1 (25th percentile): -0.71
#   Q3 (75th percentile): 0.605
#   IQR: 1.315
#   Minimum: -3.2
#   Maximum: 5.41
#   Spread: 8.61
# CF-TB:
#   Median: -0.07500000000000001
#   Q1 (25th percentile): -0.7224999999999999
#   Q3 (75th percentile): 0.435
#   IQR: 1.1575
#   Minimum: -4.18
#   Maximum: 2.37
#   Spread: 6.55
# CF-TF:
#   Median: -0.12
#   Q1 (25th percentile): -0.8725
#   Q3 (75th percentile): 0.5925
#   IQR: 1.465
#   Minimum: -3.86
#   Maximum: 2.9
#   Spread: 6.76
# AF3:
#   Median: 0.56
#   Q1 (25th percentile): -0.20500000000000002
#   Q3 (75th percentile): 1.25
#   IQR: 1.455
#   Minimum: -2.46
#   Maximum: 5.97
#   Spread: 8.43
# GT:
#   Median: -0.35
#   Q1 (25th percentile): -0.9650000000000001
#   Q3 (75th percentile): 0.24
#   IQR: 1.205
#   Minimum: -3.18
#   Maximum: 2.96
#   Spread: 6.140000000000001
# Statistics for Clashscore:
# AFM-TB:
#   Median: 14.620000000000001
#   Q1 (25th percentile): 11.6475
#   Q3 (75th percentile): 21.509999999999998
#   IQR: 9.862499999999997
#   Minimum: 7.62
#   Maximum: 57.94
#   Spread: 50.32
# AFM-TF:
#   Median: 17.42
#   Q1 (25th percentile): 14.200000000000001
#   Q3 (75th percentile): 25.107499999999998
#   IQR: 10.907499999999997
#   Minimum: 5.86
#   Maximum: 78.77
#   Spread: 72.91
# CF-TB:
#   Median: 18.36
#   Q1 (25th percentile): 13.6275
#   Q3 (75th percentile): 24.6625
#   IQR: 11.035000000000002
#   Minimum: 8.02
#   Maximum: 101.06
#   Spread: 93.04
# CF-TF:
#   Median: 22.18
#   Q1 (25th percentile): 16.7975
#   Q3 (75th percentile): 28.802500000000002
#   IQR: 12.005000000000003
#   Minimum: 9.0
#   Maximum: 103.47
#   Spread: 94.47
# AF3:
#   Median: 5.14
#   Q1 (25th percentile): 3.1550000000000002
#   Q3 (75th percentile): 7.22
#   IQR: 4.0649999999999995
#   Minimum: 0.49
#   Maximum: 32.89
#   Spread: 32.4
# GT:
#   Median: 3.37
#   Q1 (25th percentile): 2.215
#   Q3 (75th percentile): 5.109999999999999
#   IQR: 2.8949999999999996
#   Minimum: 0.31
#   Maximum: 23.24
#   Spread: 22.93

# %%
import os
import pandas as pd
import plotly.graph_objects as go

# Define the directory path where all the Excel files are located
directory_path = '/Users/neginmanshour/Desktop/PpEv/Analysis/Supplemenrary/Data/first_ranked_molprobity'

# Define the output directory to save the plot image
output_directory = '/Users/neginmanshour/Desktop/PpEv/Figures/Supplementary'

# Define the file names
file_names = ['AFM-TB.xlsx', 'AFM-TF.xlsx', 'AF3.xlsx', 'CF-TB.xlsx', 'CF-TF.xlsx', 'GT.xlsx']

# Load the data from the first sheet of each file
dfs = {file_name: pd.read_excel(os.path.join(directory_path, file_name), sheet_name='Sheet1') for file_name in file_names}

# Select the columns for the radar plot
columns_for_radar = ['Clashscore', 'Rama_Z_whole', 'Rama_Z_helix', 'Rama_Z_sheet', 'Rama_Z_loop']

# Replace 'Not Found' with NaN and convert to numeric for all datasets
for df in dfs.values():
    for column in columns_for_radar:
        df[column] = pd.to_numeric(df[column], errors='coerce')

# Normalize the values for all datasets (inverse normalization to make lower better)
normalized_dfs = {}
for file_name, df in dfs.items():
    normalized_df = (df[columns_for_radar].max() - df[columns_for_radar]) / (df[columns_for_radar].max() - df[columns_for_radar].min())
    normalized_dfs[file_name] = normalized_df

# Calculate the median values for all normalized datasets
median_values_normalized = {file_name: df.median() for file_name, df in normalized_dfs.items()}

# Print the median values for all parameters for all normalized datasets
for file_name, median_vals in median_values_normalized.items():
    print(f"\nMedian normalized values for all parameters in {file_name}:")
    for param, value in median_vals.items():
        print(f"{param}: {value}")

# Create a DataFrame to hold the median values
median_df = pd.DataFrame(median_values_normalized).T

# Initialize an empty dictionary to store the reordered data
reordered_data = {name: [0]*len(columns_for_radar) for name in median_values_normalized.keys()}

# For each parameter, reorder the datasets by their values from max to min
for i, category in enumerate(columns_for_radar):
    sorted_datasets = median_df[category].sort_values(ascending=False)
    unique_values = sorted_datasets.unique()
    value_to_rank = {value: 1 - idx / (len(unique_values) - 1) for idx, value in enumerate(unique_values)}
    for dataset_name in sorted_datasets.index:
        reordered_data[dataset_name][i] = value_to_rank[sorted_datasets[dataset_name]]

# Print the reordered values for each dataset and each parameter
for dataset_name, values in reordered_data.items():
    print(f"\nReordered values for {dataset_name}:")
    for category, value in zip(columns_for_radar, values):
        print(f"{category}: {value:.2f}")

# Prepare the categories and values for the radar plot
categories = columns_for_radar

# Create the radar plot
fig = go.Figure()

# Define colors for each dataset, making sure AF-TB and CF-TB have distinct colors
colors = {
    'AFM-TB.xlsx': 'rgba(31, 119, 180, 0.5)',   # Blue for AF-TB
    'AFM-TF.xlsx': 'rgba(255, 127, 14, 0.5)',   # Orange for AF-TF
    'AF3.xlsx': 'rgba(44, 160, 44, 0.5)',      # Green for AF3
    'CF-TB.xlsx': 'rgba(214, 39, 40, 0.5)',    # Red for CF-TB
    'CF-TF.xlsx': 'rgba(148, 103, 189, 0.5)',  # Purple for CF-TF
    'GT.xlsx': 'rgba(140, 86, 75, 0.5)'        # Brown for GT
}

# Add the datasets to the radar plot with filled lines and adjusted opacity
for dataset_name, values in reordered_data.items():
    fig.add_trace(go.Scatterpolar(
        r=values + [values[0]],  # Complete the loop
        theta=categories + [categories[0]],  # Complete the loop
        fill='toself',  # Filled lines
        opacity=0.5,  # Set the opacity to make the filled regions lighter
        name=dataset_name,
        line=dict(color=colors[dataset_name])
    ))

fig.update_layout(
    polar=dict(
        radialaxis=dict(
            visible=True,
            range=[0, 1],  # Set the range for normalized values
            showticklabels=False  # Hide the tick labels
        )),
    showlegend=True,
    title='Normalized Median Values of MolProbity Parameters'
)

# Show the plot inline
fig.show()

# Save the plot as an image with 1000 DPI
output_image_path = os.path.join(output_directory, 'Fig_S13.png')
fig.write_image(output_image_path, format='png', scale=10, engine='kaleido')

print(f'Radar plot saved at {output_image_path}')
# Out:
# Median normalized values for all parameters in AFM-TB.xlsx:
# Clashscore: 0.8608903020667726
# Rama_Z_whole: 0.5993537964458804
# Rama_Z_helix: 0.3447684391080617
# Rama_Z_sheet: 0.6137440758293837
# Rama_Z_loop: 0.6584633853541417
#
# Median normalized values for all parameters in AFM-TF.xlsx:
# Clashscore: 0.841448360993005
# Rama_Z_whole: 0.552790346907994
# Rama_Z_helix: 0.27801120448179273
# Rama_Z_sheet: 0.36690647482014394
# Rama_Z_loop: 0.6167247386759582
#
# Median normalized values for all parameters in AF3.xlsx:
# Clashscore: 0.8564814814814815
# Rama_Z_whole: 0.7392592592592593
# Rama_Z_helix: 0.417713567839196
# Rama_Z_sheet: 0.6252587991718427
# Rama_Z_loop: 0.641755634638197
#
# Median normalized values for all parameters in CF-TB.xlsx:
# Clashscore: 0.8888650042992261
# Rama_Z_whole: 0.5059880239520957
# Rama_Z_helix: 0.37847222222222227
# Rama_Z_sheet: 0.6802721088435374
# Rama_Z_loop: 0.37328244274809164
#
# Median normalized values for all parameters in CF-TF.xlsx:
# Clashscore: 0.8604848099925902
# Rama_Z_whole: 0.469470827679783
# Rama_Z_helix: 0.3638095238095238
# Rama_Z_sheet: 0.5526881720430107
# Rama_Z_loop: 0.4467455621301775
#
# Median normalized values for all parameters in GT.xlsx:
# Clashscore: 0.8665503706934147
# Rama_Z_whole: 0.565868263473054
# Rama_Z_helix: 0.3799435028248587
# Rama_Z_sheet: 0.4278557114228456
# Rama_Z_loop: 0.5390879478827361
#
# Reordered values for AFM-TB.xlsx:
# Clashscore: 0.60
# Rama_Z_whole: 0.80
# Rama_Z_helix: 0.20
# Rama_Z_sheet: 0.60
# Rama_Z_loop: 1.00
#
# Reordered values for AFM-TF.xlsx:
# Clashscore: 0.00
# Rama_Z_whole: 0.40
# Rama_Z_helix: 0.00
# Rama_Z_sheet: 0.00
# Rama_Z_loop: 0.60
#
# Reordered values for AF3.xlsx:
# Clashscore: 0.20
# Rama_Z_whole: 1.00
# Rama_Z_helix: 1.00
# Rama_Z_sheet: 0.80
# Rama_Z_loop: 0.80
#
# Reordered values for CF-TB.xlsx:
# Clashscore: 1.00
# Rama_Z_whole: 0.20
# Rama_Z_helix: 0.60
# Rama_Z_sheet: 1.00
# Rama_Z_loop: 0.00
#
# Reordered values for CF-TF.xlsx:
# Clashscore: 0.40
# Rama_Z_whole: 0.00
# Rama_Z_helix: 0.40
# Rama_Z_sheet: 0.40
# Rama_Z_loop: 0.20
#
# Reordered values for GT.xlsx:
# Clashscore: 0.80
# Rama_Z_whole: 0.60
# Rama_Z_helix: 0.80
# Rama_Z_sheet: 0.20
# Rama_Z_loop: 0.40
# Radar plot saved at /Users/neginmanshour/Desktop/PpEv/Figures/Supplementary/Fig_S13.png
